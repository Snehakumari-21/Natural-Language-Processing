# %%
import matplotlib.pyplot as plt
import nltk
from wordcloud import WordCloud

# %%
text="Hello! this is Sneha ."

# %%
wcloud= WordCloud(background_color="black").generate(" ".join(text))
plt.figure(figsize=(16,9))
plt.imshow(wcloud)
