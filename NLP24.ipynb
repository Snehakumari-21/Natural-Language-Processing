# %%
# !pip install nltk spacy textblob -U
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.0/625.0 kB 35.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.9.1
#     Uninstalling nltk-3.9.1:
#       Successfully uninstalled nltk-3.9.1
#   Attempting uninstall: textblob
#     Found existing installation: textblob 0.19.0
#     Uninstalling textblob-0.19.0:
#       Successfully uninstalled textblob-0.19.0
# ...

# %%
import nltk

# %%
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_rus to
# ...

# %%
# Word Tokenization

# %%
sent="They told that their age is 25 & 26 !"
sent.split()
# Out:
# ['They', 'told', 'that', 'their', 'age', 'is', '25', '&', '26', '!']

# %%
from nltk.tokenize import word_tokenize
word_tokenize(sent)
# Out:
# ['They', 'told', 'that', 'their', 'age', 'is', '25', '&', '26', '!']

# %%
sent= " Hello guys! how are you?"
word_tokenize(sent)
# Out:
# ['Hello', 'guys', '!', 'how', 'are', 'you', '?']

# %%
sent = "Hello friends! How are you? Welcome to NLP world."

# %%
# counts percentage of punctuation
tokens=word_tokenize(sent)

# %% [markdown]
# 1st method

# %%
cnt=0
for i in tokens:
  if i.isalnum():
    pass
  else:
    cnt+=1
print(cnt/len(tokens)*100)
# Out:
# 25.0

# %% [markdown]
# 2nd method

# %%
import string

string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
count=[word for word in tokens if word in string.punctuation]

# %%
count
# Out:
# ['!', '?']

# %%
from nltk.corpus import stopwords
from nltk.tokenize

# %%
from nltk.stem import WordNetLemmatizer
print(wnl.lemmatize("playing",pos="v"))

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
print(ps.stem("manager"))
# Out:
# manag

# %%
words1= 'managing', 'manage', 'management', 'managerial', 'managed'
words2= 'worked', 'workable', 'working', 'worked'
words3= 'big', 'biggest','bigger'
words4= 'go','gone','went','going'
words5= 'association', 'associated', 'associate'

# %%
type(words1)
#because default colection type is tuple
# Out:
# tuple

# %%
from  nltk.stem import PorterStemmer

#output may not have meaning in PorterStemmer()
ps = PorterStemmer()
print(ps.stem(words1[2]))
print(ps.stem(words3[1]))
print(ps.stem(words5[0]))
# Out:
# manag
# biggest
# associ

# %%
for word in words1:
    print(word, '-->' , ps.stem(word))
# Out:
# managing --> manag
# manage --> manag
# management --> manag
# managerial --> manageri
# managed --> manag

# %%
for word in words5:
    print(word, '-->' , ps.stem(word))
# Out:
# association --> associ
# associated --> associ
# associate --> associ
