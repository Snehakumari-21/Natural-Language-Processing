# %%
import nltk
nltk.download("wordnet")
nltk.download("stopwords")

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk.tokenize import word_tokenize
import string
from nltk import pos_tag

# %%
words1= 'managing', 'manage', 'management', 'managerial', 'managed'
words2= 'worked', 'workable', 'working', 'worked'
words3= 'big', 'biggest','bigger'
words4= 'go','gone','went','going'
words5= 'association', 'associated', 'associate'

# %%
from nltk.stem import WordNetLemmatizer

# %%
wnl= WordNetLemmatizer()

# %%
print(wnl.lemmatize("playing",pos="n"))
print(wnl.lemmatize("playing",pos="v"))
print(wnl.lemmatize("playing",pos="a"))
print(wnl.lemmatize("playing",pos="r"))
# Out:
# playing
# play
# playing
# playing

# %%
for word in words1:
    print(wnl.lemmatize(word, pos='v'))
# Out:
# manage
# manage
# management
# managerial
# manage

# %%
for word in words1:
    print(wnl.lemmatize(word, pos='v'))
# Out:
# manage
# manage
# management
# managerial
# manage
# work
# workable
# work
# work
# big
# big
# big

# %%
for word in words2:
    print(wnl.lemmatize(word, pos='v'))
# Out:
# work
# workable
# work
# work

# %%
for word in words3:
    print(wnl.lemmatize(word, pos='a'))  #adjective
# Out:
# big
# big
# big

# %%
text='''Narendra Modi is the 14th and current Prime Minister of India, serving in office since May 2014. A prominent leader of the Bharatiya Janata Party (BJP), he previously served as the Chief Minister of Gujarat from 2001 to 2014. His governance is characterized by economic reforms, digital transformation, and a strong emphasis on national development. On the global stage, he has significantly elevated India's diplomatic influence, recently upgrading international ties and receiving prestigious honors like the UN's FAO Agricola Medal for his contributions to food security and rural developmen'''

# %%
text
# Out:
# "Narendra Modi is the 14th and current Prime Minister of India, serving in office since May 2014. A prominent leader of the Bharatiya Janata Party (BJP), he previously served as the Chief Minister of Gujarat from 2001 to 2014. His governance is characterized by economic reforms, digital transformation, and a strong emphasis on national development. On the global stage, he has significantly elevated India's diplomatic influence, recently upgrading international ties and receiving prestigious honors like the UN's FAO Agricola Medal for his contributions to food security and rural developmen"

# %%
from nltk.tokenize import sent_tokenize

# %%
pg = sent_tokenize(text)

# %%
pg
# Out:
# ['Narendra Modi is the 14th and current Prime Minister of India, serving in office since May 2014.',
#  'A prominent leader of the Bharatiya Janata Party (BJP), he previously served as the Chief Minister of Gujarat from 2001 to 2014.',
#  'His governance is characterized by economic reforms, digital transformation, and a strong emphasis on national development.',
#  "On the global stage, he has significantly elevated India's diplomatic influence, recently upgrading international ties and receiving prestigious honors like the UN's FAO Agricola Medal for his contributions to food security and rural developmen"]

# %%
from nltk.tokenize  import word_tokenize

# %%
sen = sent_tokenize(text)

# %%
sen
# Out:
# ['Narendra Modi is the 14th and current Prime Minister of India, serving in office since May 2014.',
#  'A prominent leader of the Bharatiya Janata Party (BJP), he previously served as the Chief Minister of Gujarat from 2001 to 2014.',
#  'His governance is characterized by economic reforms, digital transformation, and a strong emphasis on national development.',
#  "On the global stage, he has significantly elevated India's diplomatic influence, recently upgrading international ties and receiving prestigious honors like the UN's FAO Agricola Medal for his contributions to food security and rural developmen"]

# %%
from nltk.corpus import stopwords

# Get English stopwords as a set for efficient lookup
stop_words = set(stopwords.words('english'))

# Filter out stopwords from the 'wor' list
# 'wor' contains the tokenized words from your text
filtered_words_after_stop_removal = [w for w in wd if w.lower() not in stop_words]

print("\n--- Words after Stop Word Removal ---")
print(filtered_words_after_stop_removal)
# Out:
# --- Words after Stop Word Removal ---
# ['Narendra', 'Modi', '14th', 'current', 'Prime', 'Minister', 'India', ',', 'serving', 'office', 'since', 'May', '2014', '.', 'prominent', 'leader', 'Bharatiya', 'Janata', 'Party', '(', 'BJP', ')', ',', 'previously', 'served', 'Chief', 'Minister', 'Gujarat', '2001', '2014', '.', 'governance', 'characterized', 'economic', 'reforms', ',', 'digital', 'transformation', ',', 'strong', 'emphasis', 'national', 'development', '.', 'global', 'stage', ',', 'significantly', 'elevated', 'India', "'s", 'diplomatic', 'influence', ',', 'recently', 'upgrading', 'international', 'ties', 'receiving', 'prestigious', 'honors', 'like', 'UN', "'s", 'FAO', 'Agricola', 'Medal', 'contributions', 'food', 'security', 'rural', 'developmen']

# %%
swords=stopwords.words("english")
tokens2 = [word for word in wd if word not in swords]

# %%
print(tokens2)
# Out:
# ['Narendra', 'Modi', '14th', 'current', 'Prime', 'Minister', 'India', ',', 'serving', 'office', 'since', 'May', '2014', '.', 'A', 'prominent', 'leader', 'Bharatiya', 'Janata', 'Party', '(', 'BJP', ')', ',', 'previously', 'served', 'Chief', 'Minister', 'Gujarat', '2001', '2014', '.', 'His', 'governance', 'characterized', 'economic', 'reforms', ',', 'digital', 'transformation', ',', 'strong', 'emphasis', 'national', 'development', '.', 'On', 'global', 'stage', ',', 'significantly', 'elevated', 'India', "'s", 'diplomatic', 'influence', ',', 'recently', 'upgrading', 'international', 'ties', 'receiving', 'prestigious', 'honors', 'like', 'UN', "'s", 'FAO', 'Agricola', 'Medal', 'contributions', 'food', 'security', 'rural', 'developmen']

# %%
pos = pos_tag(tokens2)
verbs=set()
for word, tag in pos:
  if tag.startswith("V") and word.isalpha():
    verbs.add(wnl.lemmatize(word.lower(),pos='v'))

# %%
verbs
# Out:
# {'characterize', 'elevate', 'receive', 'serve', 'upgrade'}

# %%
pos=pos_tag(word_tokenize((text)))

# %%
pos
# Out:
# [('Narendra', 'NNP'),
#  ('Modi', 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('14th', 'CD'),
#  ('and', 'CC'),
#  ('current', 'JJ'),
#  ('Prime', 'NNP'),
#  ('Minister', 'NNP'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  (',', ','),
#  ('serving', 'VBG'),
#  ('in', 'IN'),
#  ('office', 'NN'),
#  ('since', 'IN'),
#  ('May', 'NNP'),
#  ('2014', 'CD'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('prominent', 'JJ'),
#  ('leader', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Bharatiya', 'NNP'),
#  ('Janata', 'NNP'),
#  ('Party', 'NNP'),
#  ('(', '('),
#  ('BJP', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('he', 'PRP'),
#  ('previously', 'RB'),
#  ('served', 'VBD'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Chief', 'NNP'),
#  ('Minister', 'NNP'),
#  ('of', 'IN'),
#  ('Gujarat', 'NNP'),
#  ('from', 'IN'),
#  ('2001', 'CD'),
#  ('to', 'TO'),
#  ('2014', 'CD'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('governance', 'NN'),
#  ('is', 'VBZ'),
#  ('characterized', 'VBN'),
#  ('by', 'IN'),
# ...
